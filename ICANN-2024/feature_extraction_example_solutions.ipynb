# %% [markdown]
# ### Load example data (from CSL-SHARE database)

# %%
import utils

train_data, y_train, test_data, y_test = utils.get_train_test_data()

print("# Train : ", len(train_data))
print("# Test  : ", len(test_data))
print("Class Labels : ", set(y_train))
# Out:
# # Train :  2095
# # Test  :  655
# Class Labels :  {'walk-curve-right', 'sit', 'sit-to-stand', 'walk-curve-left', 'walk', 'stand', 'stand-to-sit'}

# %%
sample, label = utils.plot_random_sample_by_class(train_data, y_train, "walk", ylim=False)

# %%
utils.plot_sensor_data(sample, label, "Goniometer 1")

# %% [markdown]
# ### Feature Extraction with TSFEL

# %%
import tsfel

cfg = tsfel.get_features_by_domain("statistical") 

X_train = tsfel.time_series_features_extractor(cfg, train_data, fs=1000)
X_test = tsfel.time_series_features_extractor(cfg, test_data, fs=1000)
# Out:
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='2095'
#                   max='2095',
#                   style='width: 25%',
#               >
#                   2095
#               </progress>
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='655'
#                   max='655',
#                   style='width: 25%',
#               >
#                   655
#               </progress>

# %%
X_train
# Out:
#       Accelerometer Lower 1_Absolute energy  \
# 0                                 84.443735
# 1                                118.143792
# 2                                100.938194
# 3                                119.928596
# 4                                 89.343941
# ...                                     ...
# 2090                             137.664664
# 2091                             164.713474
# 2092                             129.624903
# 2093                             160.568765
# 2094                             143.553868
#
#       Accelerometer Lower 1_Average power  \
# 0                               51.209057
# 1                               62.213687
# 2                               67.337020
# 3                               74.536107
# 4                               60.408344
# ...                                   ...
# 2090                            27.649059
# 2091                            33.282173
# 2092                            26.843012
# 2093                            34.316898
# 2094                            31.350484
#
#       Accelerometer Lower 1_ECDF Percentile Count_0  \
# 0                                             330.0
# 1                                             380.0
# 2                                             300.0
# 3                                             322.0
# 4                                             296.0
# ...                                             ...
# 2090                                          996.0
# 2091                                          990.0
# 2092                                          966.0
# 2093                                          936.0
# 2094                                          916.0
#
#       Accelerometer Lower 1_ECDF Percentile Count_1  \
# 0                                            1320.0
# 1                                            1520.0
# 2                                            1200.0
# 3                                            1288.0
# 4                                            1184.0
# ...                                             ...
# 2090                                         3984.0
# 2091                                         3960.0
# 2092                                         3864.0
# 2093                                         3744.0
# 2094                                         3664.0
#
#       Accelerometer Lower 1_ECDF Percentile_0  \
# 0                                      0.2240
# 1                                      0.2472
# 2                                      0.2576
# 3                                      0.2708
# 4                                      0.2440
# ...                                       ...
# 2090                                  -0.0992
# 2091                                  -0.1152
# 2092                                  -0.1116
# 2093                                  -0.1160
# 2094                                  -0.1064
#
#       Accelerometer Lower 1_ECDF Percentile_1  Accelerometer Lower 1_ECDF_0  \
# 0                                      0.2280                      0.000606
# 1                                      0.2514                      0.000526
# 2                                      0.2616                      0.000667
# 3                                      0.2744                      0.000621
# 4                                      0.2480                      0.000676
# ...                                       ...                           ...
# 2090                                   0.1184                      0.000201
# 2091                                   0.1392                      0.000202
# 2092                                   0.1224                      0.000207
# 2093                                   0.1344                      0.000214
# 2094                                   0.1444                      0.000218
#
#       Accelerometer Lower 1_ECDF_1  Accelerometer Lower 1_ECDF_2  \
# 0                         0.001212                      0.001818
# 1                         0.001053                      0.001579
# 2                         0.001333                      0.002000
# 3                         0.001242                      0.001863
# 4                         0.001351                      0.002027
# ...                            ...                           ...
# 2090                      0.000402                      0.000602
# 2091                      0.000404                      0.000606
# 2092                      0.000414                      0.000621
# 2093                      0.000427                      0.000641
# 2094                      0.000437                      0.000655
#
#       Accelerometer Lower 1_ECDF_3  ...  Goniometer 2_Mean  \
# 0                         0.002424  ...         -81.685669
# 1                         0.002105  ...         -80.255723
# 2                         0.002667  ...         -78.919527
# 3                         0.002484  ...         -79.783058
# 4                         0.002703  ...         -79.729819
# ...                            ...  ...                ...
# 2090                      0.000803  ...         -14.181352
# 2091                      0.000808  ...         -14.093314
# 2092                      0.000828  ...         -13.510165
# 2093                      0.000855  ...         -13.646959
# 2094                      0.000873  ...         -14.638376
#
#       Goniometer 2_Mean absolute deviation  Goniometer 2_Median  \
# 0                                 0.256194           -81.620659
# 1                                 0.270297           -80.170297
# 2                                 0.239189           -78.881086
# 3                                 0.223465           -79.747274
# 4                                 0.265576           -79.679289
# ...                                    ...                  ...
# 2090                             11.649429            -7.188863
# 2091                             11.565999            -6.639941
# 2092                             12.080754            -6.000371
# 2093                             12.379544            -5.282744
# 2094                             11.773458            -7.128431
#
#       Goniometer 2_Median absolute deviation  Goniometer 2_Min  \
# 0                                   0.201439        -82.406272
# 1                                   0.206475        -81.117061
# 2                                   0.206475        -79.606267
# 3                                   0.181295        -80.553031
# 4                                   0.244245        -80.452312
# ...                                      ...               ...
# 2090                                3.827345        -49.959448
# 2091                                3.283459        -50.951536
# 2092                                3.112236        -49.833548
# 2093                                2.747128        -50.271679
# 2094                                3.409359        -50.498298
#
#       Goniometer 2_Peak to peak distance  Goniometer 2_Root mean square  \
# 0                               1.233815                      81.686271
# 1                               1.329499                      80.256382
# 2                               1.148204                      78.920090
# 3                               1.218707                      79.783553
# 4                               1.188491                      79.730470
# ...                                  ...                            ...
# 2090                           47.967717                      20.195522
# 2091                           49.080669                      20.057364
# 2092                           48.083545                      19.940911
# 2093                           48.864122                      20.323648
# 2094                           48.002969                      20.568225
#
#       Goniometer 2_Skewness  Goniometer 2_Standard deviation  \
# 0                 -0.505002                         0.313631
# 1                 -0.729945                         0.325304
# 2                 -0.690931                         0.297981
# 3                 -0.669744                         0.281014
# 4                 -0.572842                         0.322271
# ...                     ...                              ...
# 2090              -1.294199                        14.378746
# 2091              -1.338097                        14.271523
# 2092              -1.279248                        14.666811
# 2093              -1.274278                        15.060251
# 2094              -1.290492                        14.448869
#
#       Goniometer 2_Variance
# 0                  0.098364
# 1                  0.105823
# 2                  0.088792
# 3                  0.078969
# 4                  0.103858
# ...                     ...
# 2090             206.748343
# 2091             203.676356
# 2092             215.115354
# 2093             226.811157
# 2094             208.769821
#
# [2095 rows x 372 columns]

# %% [markdown]
# ### Classification with TSFEL

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score

# Remove correlated features
corr_feat = tsfel.correlated_features(X_train)
X_train.drop(corr_feat, axis=1, inplace=True)
X_test.drop(corr_feat, axis=1, inplace=True)

# Classification
clf = RandomForestClassifier(max_depth=5, random_state=1)
clf.fit(X_train, y_train)
y_pred_train = clf.predict(X_train)
y_pred = clf.predict(X_test)

print(f"Accuracy - TRAIN: {accuracy_score(y_train, y_pred_train):.3f}")
print(f"Accuracy - TEST : {accuracy_score(y_test, y_pred):.3f}")
# Out:
# Accuracy - TRAIN: 0.929
# Accuracy - TEST : 0.744

# %%
disp = ConfusionMatrixDisplay.from_predictions(y_test, y_pred, xticks_rotation="vertical") #, cmap="Greens")

# %% [markdown]
# ### Adding temporal features

# %%
cfg = tsfel.get_features_by_domain(["statistical","temporal"])

X_train = tsfel.time_series_features_extractor(cfg, train_data, fs=1000)
X_test = tsfel.time_series_features_extractor(cfg, test_data, fs=1000)

# Remove correlated features
corr_feat, X_train = tsfel.correlated_features(X_train, drop_correlated=True)
X_test.drop(corr_feat, axis=1, inplace=True)

# Classification
clf = RandomForestClassifier(max_depth=5, random_state=1)
clf.fit(X_train, y_train)
y_pred_train = clf.predict(X_train)
y_pred = clf.predict(X_test)

print(f"Accuracy - TRAIN: {accuracy_score(y_train, y_pred_train):.3f}")
print(f"Accuracy - TEST : {accuracy_score(y_test, y_pred):.3f}")
# Out:
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='2095'
#                   max='2095',
#                   style='width: 25%',
#               >
#                   2095
#               </progress>
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='655'
#                   max='655',
#                   style='width: 25%',
#               >
#                   655
#               </progress>
# Accuracy - TRAIN: 0.971
# Accuracy - TEST : 0.809

# %%
disp = ConfusionMatrixDisplay.from_predictions(y_test, y_pred, xticks_rotation="vertical") #, cmap="Greens")
